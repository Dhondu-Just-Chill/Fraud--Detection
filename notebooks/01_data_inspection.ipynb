# %%
from src.data.load_data import load_raw_data, list_raw_data_files
from src.data.validate_data import basic_checks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data.load_data import load_raw_data, list_raw_data_files
#       2 from src.data.validate_data import basic_checks
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\priya\OneDrive\Desktop\fraud-detection\venv\Scripts\python.exe
